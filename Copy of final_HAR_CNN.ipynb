# %%
# Import necessary libraries for data processing, modeling, and evaluation
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout, BatchNormalization, Input
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam

# %%
# Mount Google Drive to access the dataset stored in Google Drive (for Google Colab)
from google.colab import drive
drive.mount('/content/drive')

# Load the training and testing data
train_data = pd.read_csv('/content/drive/My Drive/archive/train.csv')
test_data = pd.read_csv('/content/drive/My Drive/archive/test.csv')
# Out:
# Mounted at /content/drive

# %%
# Extract features and labels from the training and testing data
X_train = train_data.drop(columns=['Activity'])
y_train = train_data['Activity']
X_test = test_data.drop(columns=['Activity'])
y_test = test_data['Activity']

# %%
# Map the activity labels to numerical values
activity_mapping = {'LAYING': 0, 'WALKING': 1, 'WALKING_UPSTAIRS': 2,
                    'WALKING_DOWNSTAIRS': 3, 'SITTING': 4, 'STANDING': 5}
y_train = y_train.map(activity_mapping)
y_test = y_test.map(activity_mapping)

# %%
# Convert activity labels to categorical (one-hot encoding)
y_train = to_categorical(y_train, num_classes=6)
y_test = to_categorical(y_test, num_classes=6)

# %%
# Reshape input data for Conv1D (adding a channel dimension)
X_train = X_train.values.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.values.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
# Define the CNN model architecture with Conv1D layers
def build_cnn_model():
    model = Sequential([
        Input(shape=(X_train.shape[1], 1)),  # Input layer
        Conv1D(64, kernel_size=3, activation='relu'),  # First Conv Layer
        BatchNormalization(),  # BatchNormalization after Conv Layer
        MaxPooling1D(pool_size=2),  # MaxPooling layer
        Dropout(0.3),  # Dropout for regularization

        Conv1D(128, kernel_size=3, activation='relu'),  # Second Conv Layer
        BatchNormalization(),
        MaxPooling1D(pool_size=2),
        Dropout(0.4),

        Conv1D(256, kernel_size=3, activation='relu'),  # Third Conv Layer
        BatchNormalization(),
        MaxPooling1D(pool_size=2),

        Flatten(),  # Flatten the output for Dense layers
        Dense(128, activation='relu'),  # Fully connected layer
        Dropout(0.5),  # Dropout for regularization
        Dense(6, activation='softmax')  # Output layer with 6 classes (activities)
    ])
    return model

# %%
# Initialize parameters and lists to store models and accuracies
num_models = 3
models = []
kf = KFold(n_splits=5, shuffle=True, random_state=42)
cnn_fold_accuracies = []
history_dict = {}

# %%
# Loop over to train multiple CNN models
for i in range(num_models):
    print(f"\nTraining CNN Model {i+1}")
    cnn_model = build_cnn_model()  # Build the CNN model
    cnn_model.compile(optimizer=Adam(learning_rate=0.001),  # Compile the model with Adam optimizer
                      loss='categorical_crossentropy',  # Loss function for multi-class classification
                      metrics=['accuracy'])  # Track accuracy during training

    # Perform K-Fold Cross-Validation
    for fold, (train_index, val_index) in enumerate(kf.split(X_train)):
        print(f"\nCNN Model {i+1}, Fold {fold + 1}")
        X_tr, X_val = X_train[train_index], X_train[val_index]
        y_tr, y_val = y_train[train_index], y_train[val_index]

        # Early stopping and learning rate reduction callbacks
        early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
        reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2, min_lr=1e-5)

        # Train the model on the current fold
        history = cnn_model.fit(X_tr, y_tr, validation_data=(X_val, y_val),
                                epochs=30, batch_size=32,
                                callbacks=[early_stopping, reduce_lr])

        # Evaluate the model on the validation data
        val_loss, val_accuracy = cnn_model.evaluate(X_val, y_val, verbose=0)
        cnn_fold_accuracies.append(val_accuracy)
        print(f"Model {i+1}, Fold Validation Accuracy: {val_accuracy:.4f}")

    models.append(cnn_model)  # Add the trained model to the models list
# Out:
# Training CNN Model 1
#
# CNN Model 1, Fold 1
# Epoch 1/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 43s 213ms/step - accuracy: 0.5576 - loss: 1.5918 - val_accuracy: 0.1360 - val_loss: 17.3251 - learning_rate: 0.0010
# Epoch 2/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 37s 191ms/step - accuracy: 0.8160 - loss: 0.4033 - val_accuracy: 0.5303 - val_loss: 3.6572 - learning_rate: 0.0010
# Epoch 3/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 40s 184ms/step - accuracy: 0.8473 - loss: 0.3428 - val_accuracy: 0.8314 - val_loss: 0.3951 - learning_rate: 0.0010
# Epoch 4/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 42s 189ms/step - accuracy: 0.8701 - loss: 0.3086 - val_accuracy: 0.9443 - val_loss: 0.1381 - learning_rate: 0.0010
# Epoch 5/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 36s 193ms/step - accuracy: 0.8869 - loss: 0.2586 - val_accuracy: 0.9694 - val_loss: 0.1022 - learning_rate: 0.0010
# Epoch 6/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 35s 191ms/step - accuracy: 0.8976 - loss: 0.2394 - val_accuracy: 0.9755 - val_loss: 0.1023 - learning_rate: 0.0010
# Epoch 7/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 34s 182ms/step - accuracy: 0.9037 - loss: 0.2193 - val_accuracy: 0.9776 - val_loss: 0.0915 - learning_rate: 0.0010
# Epoch 8/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 42s 188ms/step - accuracy: 0.9129 - loss: 0.2168 - val_accuracy: 0.9687 - val_loss: 0.0909 - learning_rate: 0.0010
# Epoch 9/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 36s 194ms/step - accuracy: 0.9244 - loss: 0.1826 - val_accuracy: 0.9674 - val_loss: 0.0794 - learning_rate: 0.0010
# Epoch 10/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 193ms/step - accuracy: 0.9205 - loss: 0.1767 - val_accuracy: 0.9796 - val_loss: 0.0536 - learning_rate: 0.0010
# Epoch 11/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 190ms/step - accuracy: 0.9252 - loss: 0.1792 - val_accuracy: 0.9782 - val_loss: 0.0589 - learning_rate: 0.0010
# Epoch 12/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 189ms/step - accuracy: 0.9350 - loss: 0.1502 - val_accuracy: 0.9864 - val_loss: 0.0454 - learning_rate: 0.0010
# Epoch 13/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 43s 200ms/step - accuracy: 0.9330 - loss: 0.1585 - val_accuracy: 0.9755 - val_loss: 0.0566 - learning_rate: 0.0010
# Epoch 14/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 38s 183ms/step - accuracy: 0.9386 - loss: 0.1394 - val_accuracy: 0.9728 - val_loss: 0.0666 - learning_rate: 0.0010
# Epoch 15/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 186ms/step - accuracy: 0.9434 - loss: 0.1215 - val_accuracy: 0.9796 - val_loss: 0.0581 - learning_rate: 2.0000e-04
# Epoch 16/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 188ms/step - accuracy: 0.9463 - loss: 0.1251 - val_accuracy: 0.9837 - val_loss: 0.0473 - learning_rate: 2.0000e-04
# Epoch 17/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 189ms/step - accuracy: 0.9561 - loss: 0.1051 - val_accuracy: 0.9850 - val_loss: 0.0468 - learning_rate: 4.0000e-05
# Model 1, Fold Validation Accuracy: 0.9864
#
# CNN Model 1, Fold 2
# Epoch 1/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 35s 190ms/step - accuracy: 0.9381 - loss: 0.1412 - val_accuracy: 0.9878 - val_loss: 0.0319 - learning_rate: 4.0000e-05
# Epoch 2/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 189ms/step - accuracy: 0.9462 - loss: 0.1306 - val_accuracy: 0.9878 - val_loss: 0.0296 - learning_rate: 4.0000e-05
# Epoch 3/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 187ms/step - accuracy: 0.9421 - loss: 0.1422 - val_accuracy: 0.9891 - val_loss: 0.0295 - learning_rate: 4.0000e-05
# Epoch 4/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 44s 204ms/step - accuracy: 0.9541 - loss: 0.1166 - val_accuracy: 0.9878 - val_loss: 0.0294 - learning_rate: 4.0000e-05
# Epoch 5/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 43s 213ms/step - accuracy: 0.9527 - loss: 0.1161 - val_accuracy: 0.9884 - val_loss: 0.0286 - learning_rate: 4.0000e-05
# Epoch 6/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 213ms/step - accuracy: 0.9547 - loss: 0.1134 - val_accuracy: 0.9884 - val_loss: 0.0299 - learning_rate: 4.0000e-05
# Epoch 7/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 35s 193ms/step - accuracy: 0.9588 - loss: 0.1100 - val_accuracy: 0.9871 - val_loss: 0.0293 - learning_rate: 4.0000e-05
# Epoch 8/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 40s 188ms/step - accuracy: 0.9592 - loss: 0.0916 - val_accuracy: 0.9878 - val_loss: 0.0292 - learning_rate: 1.0000e-05
# Epoch 9/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 36s 195ms/step - accuracy: 0.9531 - loss: 0.1111 - val_accuracy: 0.9871 - val_loss: 0.0293 - learning_rate: 1.0000e-05
# Epoch 10/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 40s 191ms/step - accuracy: 0.9541 - loss: 0.1090 - val_accuracy: 0.9884 - val_loss: 0.0291 - learning_rate: 1.0000e-05
# Model 1, Fold Validation Accuracy: 0.9884
#
# CNN Model 1, Fold 3
# Epoch 1/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 36s 197ms/step - accuracy: 0.9524 - loss: 0.1164 - val_accuracy: 0.9918 - val_loss: 0.0223 - learning_rate: 1.0000e-05
# Epoch 2/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 35s 191ms/step - accuracy: 0.9611 - loss: 0.1039 - val_accuracy: 0.9912 - val_loss: 0.0212 - learning_rate: 1.0000e-05
# Epoch 3/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 190ms/step - accuracy: 0.9518 - loss: 0.1119 - val_accuracy: 0.9918 - val_loss: 0.0219 - learning_rate: 1.0000e-05
# Epoch 4/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 190ms/step - accuracy: 0.9557 - loss: 0.1077 - val_accuracy: 0.9925 - val_loss: 0.0212 - learning_rate: 1.0000e-05
# Epoch 5/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 190ms/step - accuracy: 0.9564 - loss: 0.1117 - val_accuracy: 0.9918 - val_loss: 0.0220 - learning_rate: 1.0000e-05
# Epoch 6/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 190ms/step - accuracy: 0.9540 - loss: 0.1158 - val_accuracy: 0.9918 - val_loss: 0.0214 - learning_rate: 1.0000e-05
# Epoch 7/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 190ms/step - accuracy: 0.9564 - loss: 0.1044 - val_accuracy: 0.9905 - val_loss: 0.0215 - learning_rate: 1.0000e-05
# Epoch 8/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 189ms/step - accuracy: 0.9588 - loss: 0.1065 - val_accuracy: 0.9905 - val_loss: 0.0214 - learning_rate: 1.0000e-05
# Epoch 9/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 188ms/step - accuracy: 0.9523 - loss: 0.1150 - val_accuracy: 0.9912 - val_loss: 0.0209 - learning_rate: 1.0000e-05
# Epoch 10/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 189ms/step - accuracy: 0.9577 - loss: 0.1001 - val_accuracy: 0.9898 - val_loss: 0.0215 - learning_rate: 1.0000e-05
# Epoch 11/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 189ms/step - accuracy: 0.9577 - loss: 0.1161 - val_accuracy: 0.9925 - val_loss: 0.0219 - learning_rate: 1.0000e-05
# Epoch 12/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 191ms/step - accuracy: 0.9569 - loss: 0.1142 - val_accuracy: 0.9925 - val_loss: 0.0214 - learning_rate: 1.0000e-05
# Epoch 13/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 189ms/step - accuracy: 0.9570 - loss: 0.0974 - val_accuracy: 0.9912 - val_loss: 0.0215 - learning_rate: 1.0000e-05
# Epoch 14/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 42s 192ms/step - accuracy: 0.9596 - loss: 0.0990 - val_accuracy: 0.9905 - val_loss: 0.0211 - learning_rate: 1.0000e-05
# Model 1, Fold Validation Accuracy: 0.9912
#
# CNN Model 1, Fold 4
# Epoch 1/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 36s 194ms/step - accuracy: 0.9632 - loss: 0.1006 - val_accuracy: 0.9912 - val_loss: 0.0222 - learning_rate: 1.0000e-05
# Epoch 2/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 36s 194ms/step - accuracy: 0.9579 - loss: 0.1069 - val_accuracy: 0.9905 - val_loss: 0.0226 - learning_rate: 1.0000e-05
# Epoch 3/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 37s 204ms/step - accuracy: 0.9570 - loss: 0.1047 - val_accuracy: 0.9918 - val_loss: 0.0223 - learning_rate: 1.0000e-05
# Epoch 4/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 39s 196ms/step - accuracy: 0.9550 - loss: 0.1095 - val_accuracy: 0.9912 - val_loss: 0.0227 - learning_rate: 1.0000e-05
# Epoch 5/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 195ms/step - accuracy: 0.9536 - loss: 0.1067 - val_accuracy: 0.9905 - val_loss: 0.0225 - learning_rate: 1.0000e-05
# Epoch 6/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 194ms/step - accuracy: 0.9582 - loss: 0.1026 - val_accuracy: 0.9905 - val_loss: 0.0223 - learning_rate: 1.0000e-05
# Model 1, Fold Validation Accuracy: 0.9912
#
# CNN Model 1, Fold 5
# Epoch 1/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 36s 195ms/step - accuracy: 0.9611 - loss: 0.1043 - val_accuracy: 0.9925 - val_loss: 0.0177 - learning_rate: 1.0000e-05
# Epoch 2/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 42s 198ms/step - accuracy: 0.9582 - loss: 0.1104 - val_accuracy: 0.9946 - val_loss: 0.0175 - learning_rate: 1.0000e-05
# Epoch 3/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 40s 193ms/step - accuracy: 0.9601 - loss: 0.1034 - val_accuracy: 0.9939 - val_loss: 0.0176 - learning_rate: 1.0000e-05
# Epoch 4/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 192ms/step - accuracy: 0.9539 - loss: 0.1152 - val_accuracy: 0.9939 - val_loss: 0.0179 - learning_rate: 1.0000e-05
# Epoch 5/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 192ms/step - accuracy: 0.9606 - loss: 0.1034 - val_accuracy: 0.9939 - val_loss: 0.0174 - learning_rate: 1.0000e-05
# Epoch 6/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 193ms/step - accuracy: 0.9548 - loss: 0.1021 - val_accuracy: 0.9952 - val_loss: 0.0174 - learning_rate: 1.0000e-05
# Epoch 7/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 40s 189ms/step - accuracy: 0.9534 - loss: 0.0983 - val_accuracy: 0.9925 - val_loss: 0.0177 - learning_rate: 1.0000e-05
# Epoch 8/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 42s 193ms/step - accuracy: 0.9599 - loss: 0.0968 - val_accuracy: 0.9952 - val_loss: 0.0171 - learning_rate: 1.0000e-05
# Epoch 9/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 44s 208ms/step - accuracy: 0.9595 - loss: 0.0977 - val_accuracy: 0.9952 - val_loss: 0.0169 - learning_rate: 1.0000e-05
# Epoch 10/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 35s 193ms/step - accuracy: 0.9578 - loss: 0.0997 - val_accuracy: 0.9932 - val_loss: 0.0177 - learning_rate: 1.0000e-05
# Epoch 11/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 43s 203ms/step - accuracy: 0.9636 - loss: 0.0841 - val_accuracy: 0.9925 - val_loss: 0.0177 - learning_rate: 1.0000e-05
# Epoch 12/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 205ms/step - accuracy: 0.9521 - loss: 0.1081 - val_accuracy: 0.9946 - val_loss: 0.0174 - learning_rate: 1.0000e-05
# Epoch 13/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 37s 202ms/step - accuracy: 0.9555 - loss: 0.1067 - val_accuracy: 0.9939 - val_loss: 0.0174 - learning_rate: 1.0000e-05
# Epoch 14/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 42s 205ms/step - accuracy: 0.9570 - loss: 0.1054 - val_accuracy: 0.9939 - val_loss: 0.0172 - learning_rate: 1.0000e-05
# Model 1, Fold Validation Accuracy: 0.9952
#
# Training CNN Model 2
#
# CNN Model 2, Fold 1
# Epoch 1/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 40s 194ms/step - accuracy: 0.5427 - loss: 1.5735 - val_accuracy: 0.1679 - val_loss: 13.9796 - learning_rate: 0.0010
# Epoch 2/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 43s 206ms/step - accuracy: 0.7883 - loss: 0.4691 - val_accuracy: 0.1808 - val_loss: 5.1686 - learning_rate: 0.0010
# Epoch 3/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 40s 202ms/step - accuracy: 0.8538 - loss: 0.3421 - val_accuracy: 0.9354 - val_loss: 0.2009 - learning_rate: 0.0010
# Epoch 4/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 36s 194ms/step - accuracy: 0.8721 - loss: 0.2993 - val_accuracy: 0.9545 - val_loss: 0.1213 - learning_rate: 0.0010
# Epoch 5/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 194ms/step - accuracy: 0.8967 - loss: 0.2521 - val_accuracy: 0.9742 - val_loss: 0.0824 - learning_rate: 0.0010
# Epoch 6/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 193ms/step - accuracy: 0.9111 - loss: 0.2185 - val_accuracy: 0.9585 - val_loss: 0.1057 - learning_rate: 0.0010
# Epoch 7/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 193ms/step - accuracy: 0.9108 - loss: 0.2260 - val_accuracy: 0.9708 - val_loss: 0.0729 - learning_rate: 0.0010
# Epoch 8/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 40s 190ms/step - accuracy: 0.9267 - loss: 0.1770 - val_accuracy: 0.9796 - val_loss: 0.0584 - learning_rate: 0.0010
# Epoch 9/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 192ms/step - accuracy: 0.9354 - loss: 0.1601 - val_accuracy: 0.9830 - val_loss: 0.0502 - learning_rate: 0.0010
# Epoch 10/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 35s 189ms/step - accuracy: 0.9366 - loss: 0.1572 - val_accuracy: 0.9714 - val_loss: 0.0771 - learning_rate: 0.0010
# Epoch 11/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 42s 195ms/step - accuracy: 0.9437 - loss: 0.1487 - val_accuracy: 0.9782 - val_loss: 0.0729 - learning_rate: 0.0010
# Epoch 12/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 40s 188ms/step - accuracy: 0.9474 - loss: 0.1326 - val_accuracy: 0.9810 - val_loss: 0.0505 - learning_rate: 2.0000e-04
# Epoch 13/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 42s 193ms/step - accuracy: 0.9619 - loss: 0.0949 - val_accuracy: 0.9823 - val_loss: 0.0551 - learning_rate: 2.0000e-04
# Epoch 14/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 37s 201ms/step - accuracy: 0.9520 - loss: 0.1042 - val_accuracy: 0.9830 - val_loss: 0.0520 - learning_rate: 4.0000e-05
# Model 2, Fold Validation Accuracy: 0.9830
#
# CNN Model 2, Fold 2
# Epoch 1/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 36s 195ms/step - accuracy: 0.9371 - loss: 0.1510 - val_accuracy: 0.9830 - val_loss: 0.0339 - learning_rate: 4.0000e-05
# Epoch 2/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 42s 200ms/step - accuracy: 0.9474 - loss: 0.1276 - val_accuracy: 0.9823 - val_loss: 0.0331 - learning_rate: 4.0000e-05
# Epoch 3/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 40s 192ms/step - accuracy: 0.9488 - loss: 0.1301 - val_accuracy: 0.9857 - val_loss: 0.0303 - learning_rate: 4.0000e-05
# Epoch 4/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 191ms/step - accuracy: 0.9534 - loss: 0.1166 - val_accuracy: 0.9837 - val_loss: 0.0316 - learning_rate: 4.0000e-05
# Epoch 5/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 34s 183ms/step - accuracy: 0.9549 - loss: 0.1084 - val_accuracy: 0.9837 - val_loss: 0.0344 - learning_rate: 4.0000e-05
# Epoch 6/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 42s 189ms/step - accuracy: 0.9542 - loss: 0.1129 - val_accuracy: 0.9844 - val_loss: 0.0320 - learning_rate: 1.0000e-05
# Epoch 7/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 189ms/step - accuracy: 0.9539 - loss: 0.1181 - val_accuracy: 0.9850 - val_loss: 0.0310 - learning_rate: 1.0000e-05
# Epoch 8/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 40s 184ms/step - accuracy: 0.9519 - loss: 0.1155 - val_accuracy: 0.9850 - val_loss: 0.0314 - learning_rate: 1.0000e-05
# Model 2, Fold Validation Accuracy: 0.9857
#
# CNN Model 2, Fold 3
# Epoch 1/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 35s 192ms/step - accuracy: 0.9531 - loss: 0.1156 - val_accuracy: 0.9912 - val_loss: 0.0222 - learning_rate: 1.0000e-05
# Epoch 2/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 192ms/step - accuracy: 0.9564 - loss: 0.1155 - val_accuracy: 0.9918 - val_loss: 0.0211 - learning_rate: 1.0000e-05
# Epoch 3/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 40s 189ms/step - accuracy: 0.9509 - loss: 0.1293 - val_accuracy: 0.9925 - val_loss: 0.0213 - learning_rate: 1.0000e-05
# Epoch 4/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 189ms/step - accuracy: 0.9522 - loss: 0.1156 - val_accuracy: 0.9918 - val_loss: 0.0210 - learning_rate: 1.0000e-05
# Epoch 5/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 190ms/step - accuracy: 0.9523 - loss: 0.1204 - val_accuracy: 0.9925 - val_loss: 0.0214 - learning_rate: 1.0000e-05
# Epoch 6/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 189ms/step - accuracy: 0.9516 - loss: 0.1253 - val_accuracy: 0.9918 - val_loss: 0.0211 - learning_rate: 1.0000e-05
# Epoch 7/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 189ms/step - accuracy: 0.9492 - loss: 0.1280 - val_accuracy: 0.9925 - val_loss: 0.0212 - learning_rate: 1.0000e-05
# Epoch 8/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 191ms/step - accuracy: 0.9482 - loss: 0.1243 - val_accuracy: 0.9925 - val_loss: 0.0221 - learning_rate: 1.0000e-05
# Epoch 9/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 43s 203ms/step - accuracy: 0.9605 - loss: 0.1074 - val_accuracy: 0.9925 - val_loss: 0.0219 - learning_rate: 1.0000e-05
# Model 2, Fold Validation Accuracy: 0.9918
#
# CNN Model 2, Fold 4
# Epoch 1/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 40s 217ms/step - accuracy: 0.9587 - loss: 0.1061 - val_accuracy: 0.9891 - val_loss: 0.0245 - learning_rate: 1.0000e-05
# Epoch 2/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 39s 206ms/step - accuracy: 0.9540 - loss: 0.1142 - val_accuracy: 0.9898 - val_loss: 0.0238 - learning_rate: 1.0000e-05
# Epoch 3/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 40s 202ms/step - accuracy: 0.9503 - loss: 0.1235 - val_accuracy: 0.9878 - val_loss: 0.0245 - learning_rate: 1.0000e-05
# Epoch 4/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 40s 196ms/step - accuracy: 0.9514 - loss: 0.1085 - val_accuracy: 0.9884 - val_loss: 0.0241 - learning_rate: 1.0000e-05
# Epoch 5/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 40s 191ms/step - accuracy: 0.9525 - loss: 0.1226 - val_accuracy: 0.9891 - val_loss: 0.0242 - learning_rate: 1.0000e-05
# Epoch 6/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 46s 218ms/step - accuracy: 0.9546 - loss: 0.1140 - val_accuracy: 0.9898 - val_loss: 0.0239 - learning_rate: 1.0000e-05
# Epoch 7/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 37s 195ms/step - accuracy: 0.9522 - loss: 0.1178 - val_accuracy: 0.9898 - val_loss: 0.0241 - learning_rate: 1.0000e-05
# Model 2, Fold Validation Accuracy: 0.9898
#
# CNN Model 2, Fold 5
# Epoch 1/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 37s 199ms/step - accuracy: 0.9565 - loss: 0.1088 - val_accuracy: 0.9918 - val_loss: 0.0226 - learning_rate: 1.0000e-05
# Epoch 2/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 42s 203ms/step - accuracy: 0.9504 - loss: 0.1188 - val_accuracy: 0.9918 - val_loss: 0.0223 - learning_rate: 1.0000e-05
# Epoch 3/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 35s 189ms/step - accuracy: 0.9571 - loss: 0.1090 - val_accuracy: 0.9918 - val_loss: 0.0222 - learning_rate: 1.0000e-05
# Epoch 4/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 43s 198ms/step - accuracy: 0.9534 - loss: 0.1145 - val_accuracy: 0.9918 - val_loss: 0.0222 - learning_rate: 1.0000e-05
# Epoch 5/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 42s 203ms/step - accuracy: 0.9511 - loss: 0.1140 - val_accuracy: 0.9918 - val_loss: 0.0221 - learning_rate: 1.0000e-05
# Epoch 6/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 40s 197ms/step - accuracy: 0.9563 - loss: 0.1126 - val_accuracy: 0.9912 - val_loss: 0.0227 - learning_rate: 1.0000e-05
# Epoch 7/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 198ms/step - accuracy: 0.9531 - loss: 0.1126 - val_accuracy: 0.9912 - val_loss: 0.0224 - learning_rate: 1.0000e-05
# Epoch 8/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 40s 193ms/step - accuracy: 0.9599 - loss: 0.1060 - val_accuracy: 0.9912 - val_loss: 0.0225 - learning_rate: 1.0000e-05
# Epoch 9/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 42s 197ms/step - accuracy: 0.9648 - loss: 0.0967 - val_accuracy: 0.9912 - val_loss: 0.0224 - learning_rate: 1.0000e-05
# Epoch 10/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 196ms/step - accuracy: 0.9592 - loss: 0.1047 - val_accuracy: 0.9912 - val_loss: 0.0223 - learning_rate: 1.0000e-05
# Model 2, Fold Validation Accuracy: 0.9918
#
# Training CNN Model 3
#
# CNN Model 3, Fold 1
# Epoch 1/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 43s 205ms/step - accuracy: 0.4931 - loss: 1.8599 - val_accuracy: 0.1679 - val_loss: 37.4065 - learning_rate: 0.0010
# Epoch 2/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 42s 211ms/step - accuracy: 0.7376 - loss: 0.5963 - val_accuracy: 0.1679 - val_loss: 24.8500 - learning_rate: 0.0010
# Epoch 3/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 38s 209ms/step - accuracy: 0.8040 - loss: 0.4375 - val_accuracy: 0.6934 - val_loss: 1.6362 - learning_rate: 0.0010
# Epoch 4/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 209ms/step - accuracy: 0.8137 - loss: 0.4118 - val_accuracy: 0.9422 - val_loss: 0.1860 - learning_rate: 0.0010
# Epoch 5/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 40s 207ms/step - accuracy: 0.8487 - loss: 0.3549 - val_accuracy: 0.9375 - val_loss: 0.1583 - learning_rate: 0.0010
# Epoch 6/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 208ms/step - accuracy: 0.8781 - loss: 0.3100 - val_accuracy: 0.9089 - val_loss: 0.1747 - learning_rate: 0.0010
# Epoch 7/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 36s 196ms/step - accuracy: 0.8897 - loss: 0.3036 - val_accuracy: 0.9524 - val_loss: 0.1765 - learning_rate: 0.0010
# Epoch 8/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 42s 202ms/step - accuracy: 0.9118 - loss: 0.2245 - val_accuracy: 0.9619 - val_loss: 0.0968 - learning_rate: 2.0000e-04
# Epoch 9/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 202ms/step - accuracy: 0.9277 - loss: 0.1935 - val_accuracy: 0.9640 - val_loss: 0.0871 - learning_rate: 2.0000e-04
# Epoch 10/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 46s 228ms/step - accuracy: 0.9413 - loss: 0.1601 - val_accuracy: 0.9728 - val_loss: 0.0712 - learning_rate: 2.0000e-04
# Epoch 11/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 79s 213ms/step - accuracy: 0.9460 - loss: 0.1416 - val_accuracy: 0.9755 - val_loss: 0.0730 - learning_rate: 2.0000e-04
# Epoch 12/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 211ms/step - accuracy: 0.9395 - loss: 0.1539 - val_accuracy: 0.9755 - val_loss: 0.0654 - learning_rate: 2.0000e-04
# Epoch 13/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 40s 208ms/step - accuracy: 0.9438 - loss: 0.1429 - val_accuracy: 0.9755 - val_loss: 0.0651 - learning_rate: 2.0000e-04
# Epoch 14/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 41s 206ms/step - accuracy: 0.9503 - loss: 0.1333 - val_accuracy: 0.9776 - val_loss: 0.0638 - learning_rate: 2.0000e-04
# Epoch 15/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 37s 200ms/step - accuracy: 0.9510 - loss: 0.1203 - val_accuracy: 0.9776 - val_loss: 0.0575 - learning_rate: 2.0000e-04
# Epoch 16/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 39s 191ms/step - accuracy: 0.9513 - loss: 0.1284 - val_accuracy: 0.9701 - val_loss: 0.0735 - learning_rate: 2.0000e-04
# Epoch 17/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 44s 206ms/step - accuracy: 0.9564 - loss: 0.1164 - val_accuracy: 0.9796 - val_loss: 0.0598 - learning_rate: 2.0000e-04
# Epoch 18/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 38s 189ms/step - accuracy: 0.9664 - loss: 0.1044 - val_accuracy: 0.9769 - val_loss: 0.0590 - learning_rate: 4.0000e-05
# Epoch 19/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 42s 197ms/step - accuracy: 0.9683 - loss: 0.0992 - val_accuracy: 0.9796 - val_loss: 0.0549 - learning_rate: 4.0000e-05
# Epoch 20/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 45s 221ms/step - accuracy: 0.9641 - loss: 0.1021 - val_accuracy: 0.9823 - val_loss: 0.0540 - learning_rate: 4.0000e-05
# Epoch 21/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 37s 197ms/step - accuracy: 0.9665 - loss: 0.0952 - val_accuracy: 0.9823 - val_loss: 0.0519 - learning_rate: 4.0000e-05
# Epoch 22/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 43s 209ms/step - accuracy: 0.9635 - loss: 0.0955 - val_accuracy: 0.9782 - val_loss: 0.0572 - learning_rate: 4.0000e-05
# Epoch 23/30
# 184/184 ━━━━━━━━━━━━━━━━━━━━ 36s 196ms/step - accuracy: 0.9629 - loss: 0.0938 - val_accuracy: 0.9776 - val_loss: 0.0560 - learning_rate: 4.0000e-05
# Epoch 24/30
#  82/184 ━━━━━━━━━━━━━━━━━━━━ 19s 187ms/step - accuracy: 0.9573 - loss: 0.1145

# %%
# Function to predict with an ensemble of models by averaging their predictions
def model_ensemble_predict(models, X):
    # Get predictions from each model and average them
    predictions = [model.predict(X) for model in models]
    averaged_predictions = np.mean(predictions, axis=0)  # Average across all models
    return averaged_predictions

# %%
# Evaluate ensemble model on the test set
ensemble_predictions = model_ensemble_predict(models, X_test)

# %%
# Calculate test accuracy of the ensemble model
ensemble_test_accuracy = np.mean(np.argmax(ensemble_predictions, axis=1) == np.argmax(y_test, axis=1))
print(f"Ensemble Test Accuracy: {ensemble_test_accuracy:.4f}")

# %%
# Evaluate on Test Set using Ensemble
ensemble_predictions = model_ensemble_predict(models, X_test)
ensemble_test_accuracy = np.mean(np.argmax(ensemble_predictions, axis=1) == np.argmax(y_test, axis=1))
print(f"Ensemble Test Accuracy: {ensemble_test_accuracy:.4f}")

# %%
# Classification Report for Ensemble
print("\nClassification Report for Ensemble:")
print(classification_report(y_true, y_pred_ensemble, target_names=activity_mapping.keys()))

# %%
# Confusion Matrix for Ensemble
y_pred_ensemble = ensemble_predictions.argmax(axis=1)
y_true = y_test.argmax(axis=1)
cm_ensemble = confusion_matrix(y_true, y_pred_ensemble)

# %%
# Plot Confusion Matrix for Ensemble
plt.figure(figsize=(8, 6))
sns.heatmap(cm_ensemble, annot=True, fmt='d', cmap='Blues', xticklabels=activity_mapping.keys(), yticklabels=activity_mapping.keys())
plt.title('Ensemble Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have 'cnn_fold_accuracies' from your original code

# Reshape accuracies to (num_models, num_folds)
num_folds = 5  # Number of folds in KFold
cnn_fold_accuracies_reshaped = np.array(cnn_fold_accuracies).reshape(num_models, num_folds)

# Calculate mean and standard deviation across folds for each model
mean_accuracies = np.mean(cnn_fold_accuracies_reshaped, axis=1)
std_accuracies = np.std(cnn_fold_accuracies_reshaped, axis=1)

# Plotting Accuracy across Folds for Each Model
plt.figure(figsize=(10, 6))
for i in range(num_models):
    plt.plot(range(1, num_folds + 1), cnn_fold_accuracies_reshaped[i], label=f"Model {i + 1}")
    plt.errorbar(range(1, num_folds + 1), cnn_fold_accuracies_reshaped[i], yerr=std_accuracies[i], fmt='o', capsize=5)

plt.title("Accuracy across Folds for Each Model in Ensemble")
plt.xlabel("Fold")
plt.ylabel("Accuracy")
plt.legend()
plt.grid(True)
plt.show()
